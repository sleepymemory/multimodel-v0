# %%
import os
from tqdm import tqdm
from torch import nn, optim
import torch
from torch.utils.data import DataLoader
from dataloader import *
from model import *
from torchvision.utils import save_image

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = SensorFusion(device=device).to(device)

weights = r'log\5C\models\weights_itr_300.pth'

if os.path.exists(weights):
    model.load_state_dict(torch.load(weights))
    print('successfully')
else:
    print('no loading')
# Out:
# successfully

# %%
ls=[]
real=[]

loss_P = nn.MSELoss()
loss_F = nn.MSELoss()
loss_D = nn.MSELoss()
val_path = r'C:\Users\Paradox\Desktop\git\test_data\val'

filename_list = []
for i in range(len(os.listdir(os.path.join(val_path, "D_real")))):
    filename_list.append("{}.npy".format(i))

datasets_val = DataLoader(MyDataset(val_path, filename_list), batch_size=1, shuffle=False)

epoch_loss = 0
model.eval()
val_loop = tqdm(datasets_val)
for i, (image, us_image, F, P, D, label_F, label_P, label_D) in enumerate(val_loop):
    image = image.to(device)
    us_image = us_image.to(device)

    F = F.to(device)
    P = P.to(device)
    D = D.to(device)

    label_F = label_F.to(device)
    label_P = label_P.to(device)
    label_D = label_D.to(device)
    real.append(P)

    F_out, P_out, D_out = model(image, us_image, F, P, D)
    
    
    F_loss=loss_F(F_out,label_F)
    P_loss=loss_P(P_out,label_P)
    D_loss=loss_D(D_out,label_D)
        
    total_loss=(F_loss+P_loss+D_loss)
    val_loop.set_postfix(F_loss_=F_loss.item(), D_loss=D_loss.item(), P_loss=P_loss.item())
    epoch_loss+=total_loss.item()
    
    P_out=P_out.squeeze(dim=0)
    P_out=P_out.cpu().detach().numpy()/10000

    
    
    ls.append(P_out)
    
print(epoch_loss)
# Out:
# 100%|██████████████████████████████| 240/240 [00:07<00:00, 31.55it/s, D_loss=0.000311, F_loss_=1.44e+3, P_loss=2.38e+3]
# 594199.4967041016

# %%
real=[i[0].cpu().detach().numpy()/10000 for i in real]

# %%
real
# Out:
# [array([ 0.4685568 , -0.04418181,  0.11679167], dtype=float32),
#  array([ 0.4685541 , -0.04418056,  0.11678787], dtype=float32),
#  array([ 0.46854952, -0.04418018,  0.11678088], dtype=float32),
#  array([ 0.4685479 , -0.04418015,  0.11677866], dtype=float32),
#  array([ 0.46854365, -0.04417696,  0.11677224], dtype=float32),
#  array([ 0.46853888, -0.04417521,  0.1167682 ], dtype=float32),
#  array([ 0.46853676, -0.04417633,  0.11676456], dtype=float32),
#  array([ 0.46853745, -0.04417486,  0.1167645 ], dtype=float32),
#  array([ 0.46853307, -0.04417629,  0.11676004], dtype=float32),
#  array([ 0.46853042, -0.04417619,  0.11675637], dtype=float32),
#  array([ 0.46853125, -0.0441751 ,  0.11675718], dtype=float32),
#  array([ 0.46852982, -0.04417461,  0.1167549 ], dtype=float32),
#  array([ 0.46852794, -0.04417585,  0.11675075], dtype=float32),
#  array([ 0.4685247 , -0.04417728,  0.11674731], dtype=float32),
#  array([ 0.4685268 , -0.04417589,  0.11674894], dtype=float32),
#  array([ 0.4685227 , -0.04417571,  0.11674473], dtype=float32),
#  array([ 0.47198075, -0.05382518,  0.03088524], dtype=float32),
#  array([ 0.47209668, -0.05388093,  0.03063499], dtype=float32),
#  array([ 0.4724118 , -0.05395501,  0.03032582], dtype=float32),
#  array([ 0.4726294 , -0.05397859,  0.03022276], dtype=float32),
#  array([ 0.47265762, -0.05399291,  0.03016337], dtype=float32),
#  array([ 0.47267646, -0.05402311,  0.03004696], dtype=float32),
#  array([ 0.47263873, -0.05404735,  0.02996873], dtype=float32),
#  array([ 0.47257802, -0.05407681,  0.02985407], dtype=float32),
#  array([ 0.47253388, -0.05409551,  0.02978548], dtype=float32),
#  array([ 0.47248873, -0.05411444,  0.02971559], dtype=float32),
#  array([ 0.47245854, -0.05412807,  0.02967049], dtype=float32),
#  array([ 0.4724397 , -0.05413543,  0.02964166], dtype=float32),
#  array([ 0.47242466, -0.05414258,  0.02961943], dtype=float32),
#  array([ 0.47241953, -0.05414601,  0.02961004], dtype=float32),
#  array([ 0.4724142 , -0.05414807,  0.02960125], dtype=float32),
#  array([ 0.47241163, -0.05414863,  0.02959673], dtype=float32),
#  array([ 0.4724099 , -0.05414841,  0.02959171], dtype=float32),
#  array([ 0.4724099 , -0.05415136,  0.02959001], dtype=float32),
#  array([ 0.4724095 , -0.05415035,  0.02958692], dtype=float32),
#  array([ 0.47240567, -0.05415116,  0.02958334], dtype=float32),
#  array([ 0.47240597, -0.0541527 ,  0.02958   ], dtype=float32),
#  array([ 0.47240424, -0.05415391,  0.0295777 ], dtype=float32),
#  array([ 0.47240326, -0.05415286,  0.02957574], dtype=float32),
#  array([ 0.47240192, -0.05415443,  0.02957282], dtype=float32),
#  array([ 0.4724002 , -0.05415472,  0.02956964], dtype=float32),
#  array([ 0.4723979 , -0.05415478,  0.02956579], dtype=float32),
#  array([ 0.47239712, -0.05415499,  0.0295642 ], dtype=float32),
#  array([ 0.47239834, -0.05415515,  0.02956335], dtype=float32),
#  array([ 0.47239298, -0.05415775,  0.02955878], dtype=float32),
#  array([ 0.47239664, -0.05415776,  0.02955901], dtype=float32),
#  array([ 0.47239664, -0.05415882,  0.0295592 ], dtype=float32),
#  array([ 0.47239405, -0.05416078,  0.02955555], dtype=float32),
#  array([ 0.47239423, -0.05416032,  0.02955462], dtype=float32),
#  array([ 0.47239184, -0.05416031,  0.02955242], dtype=float32),
#  array([ 0.47239223, -0.05415824,  0.02955068], dtype=float32),
#  array([ 0.4723917 , -0.05415953,  0.0295492 ], dtype=float32),
#  array([ 0.4723932 , -0.05416042,  0.0295498 ], dtype=float32),
#  array([ 0.4723887 , -0.05416103,  0.02954594], dtype=float32),
#  array([ 0.47239038, -0.05416078,  0.02954697], dtype=float32),
#  array([ 0.47238734, -0.05416147,  0.02954318], dtype=float32),
#  array([ 0.47239023, -0.05416124,  0.02954589], dtype=float32),
#  array([ 0.47239003, -0.05416068,  0.02954427], dtype=float32),
#  array([ 0.4723871 , -0.05416204,  0.02954185], dtype=float32),
#  array([ 0.4714042 , -0.04584528,  0.02088059], dtype=float32),
#  array([ 0.47148716, -0.04569359,  0.020803  ], dtype=float32),
#  array([ 0.47148585, -0.04574736,  0.02076215], dtype=float32),
#  array([ 0.47155538, -0.04576624,  0.02083317], dtype=float32),
#  array([ 0.47155464, -0.04576365,  0.02076007], dtype=float32),
#  array([ 0.47156367, -0.04576207,  0.02087074], dtype=float32),
#  array([ 0.47151044, -0.0456844 ,  0.020822  ], dtype=float32),
#  array([ 0.47153607, -0.04575543,  0.02085295], dtype=float32),
#  array([ 0.47159111, -0.04573422,  0.02077447], dtype=float32),
#  array([ 0.47149336, -0.04569672,  0.0207864 ], dtype=float32),
#  array([ 0.47158277, -0.04566851,  0.02071342], dtype=float32),
#  array([ 0.47148275, -0.04570463,  0.02074994], dtype=float32),
#  array([ 0.47144   , -0.04582416,  0.02083158], dtype=float32),
#  array([ 0.4714351 , -0.04567999,  0.02077767], dtype=float32),
#  array([ 0.47162884, -0.04562186,  0.02076662], dtype=float32),
#  array([ 0.47159258, -0.04561486,  0.02077657], dtype=float32),
#  array([ 0.47154108, -0.0456047 ,  0.02080191], dtype=float32),
#  array([ 0.4714895 , -0.04572971,  0.02077302], dtype=float32),
#  array([ 0.47146416, -0.045672  ,  0.02081203], dtype=float32),
#  array([ 0.47144535, -0.04581886,  0.02088837], dtype=float32),
#  array([ 0.47164166, -0.04560703,  0.02074534], dtype=float32),
#  array([ 0.47157836, -0.04561055,  0.02081938], dtype=float32),
#  array([ 0.47149298, -0.04570536,  0.02084937], dtype=float32),
#  array([ 0.47152647, -0.04568095,  0.02082818], dtype=float32),
#  array([ 0.4716168 , -0.04559589,  0.02076968], dtype=float32),
#  array([ 0.47144252, -0.04569304,  0.02088301], dtype=float32),
#  array([ 0.47156495, -0.04573594,  0.02081753], dtype=float32),
#  array([ 0.47145885, -0.04557156,  0.02071739], dtype=float32),
#  array([ 0.47162822, -0.04565345,  0.02075608], dtype=float32),
#  array([ 0.4716043 , -0.04550302,  0.0206741 ], dtype=float32),
#  array([ 0.4715818 , -0.04575991,  0.02082364], dtype=float32),
#  array([ 0.47148824, -0.04570631,  0.02085178], dtype=float32)]

# %%
import matplotlib.pyplot as plt
x=np.arange(1,len(ls)+1)

# %%
real_P_Z=[]
predict_P_Z=[]
real_P_X=[]
predict_P_X=[]
real_P_Y=[]
predict_P_Y=[]
for i in range(len(real)):
    real_P_Z.append(real[i][2])
    predict_P_Z.append(ls[i][2])
    real_P_X.append(real[i][0])
    predict_P_X.append(ls[i][0])
    real_P_Y.append(real[i][1])
    predict_P_Y.append(ls[i][1])

# %%
x=np.arange(1,len(real_P_Z)+1)
plt.plot(x,real_P_Z)
plt.plot(x,predict_P_Z)
plt.show()

# %%
x=np.arange(1,len(real_P_X)+1)
plt.plot(x,real_P_X)
plt.plot(x,predict_P_X)
plt.show()

# %%
x=np.arange(1,len(real_P_Y)+1)
plt.plot(x,real_P_Y)
plt.plot(x,predict_P_Y)
plt.show()

# %%
test_path=r"C:\Users\Paradox\Desktop\git\test_data_2\test_data\2"
P=np.load(os.path.join(test_path,"P.npy"))
P=torch.Tensor(P)
F=np.load(os.path.join(test_path,"F.npy"))
F=torch.Tensor(F)
D=np.load(os.path.join(test_path,"D.npy"))
D=torch.Tensor(D)
image=cv2.imread(r"C:\Users\Paradox\Desktop\git\test_data_2\test_data\2\RGB.png")
us_image=cv2.imread(r"C:\Users\Paradox\Desktop\git\test_data_2\test_data\2\US.png")

rgb_img = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
rgb_temp = max(rgb_img.size)

rgb_mask = Image.new('RGB', (rgb_temp, rgb_temp))
rgb_mask.paste(rgb_img, (0, 0))
rgb_img = rgb_mask.resize((256, 256))



rgb_img_data = transform(rgb_img)
rgb_img_data = torch.unsqueeze(rgb_img_data, dim=0)

us_image=us_image[100:400, 140:500]
us_image = Image.fromarray(cv2.cvtColor(us_image, cv2.COLOR_BGR2RGB))
us_temp = max(us_image.size)

us_mask = Image.new('RGB', (us_temp, us_temp))
us_mask.paste(us_image, (0, 0))
us_mask = us_mask.resize((256, 256))


us_img_data = transform(us_mask)
us_img_data = torch.unsqueeze(us_img_data, dim=0)
F = F.to(device)
P = P.to(device)
D = D.to(device)
rgb_img_data= rgb_img_data.to(device)
us_img_data= us_img_data.to(device)
F_out, P_out, D_out = model(rgb_img_data, us_img_data, F, P, D)

P_out=P_out.squeeze(dim=0)
P_out=P_out.cpu().detach().numpy()/10000
P=P.squeeze(dim=0)
P=P.cpu().detach().numpy()/10000
print(P_out)
print(P)
print(D)
print(F)
# Out:
# [ 0.50229234 -0.04636418  0.06442272]
# [ 0.48316693 -0.04895843  0.06329051]
# tensor([[ 0.7368,  0.6761, -0.0059,  0.0020]], device='cuda:0')
# tensor([[-22.2000,   2.5000,  62.7000]], device='cuda:0')

# %%
test_path=r"C:\Users\Paradox\Desktop\git\test_data_2\test_data\2"
P=np.load(os.path.join(test_path,"P.npy"))
P=torch.Tensor(P)
F=np.load(os.path.join(test_path,"F.npy"))
F=torch.Tensor(F)
D=np.load(os.path.join(test_path,"D.npy"))
D=torch.Tensor(D)
image=cv2.imread(os.path,join(test_path,"RGB.png"))
us_image=cv2.imread(os.path,join(test_path,"US.png"))

rgb_img = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
rgb_temp = max(rgb_img.size)

rgb_mask = Image.new('RGB', (rgb_temp, rgb_temp))
rgb_mask.paste(rgb_img, (0, 0))
rgb_img = rgb_mask.resize((256, 256))



rgb_img_data = transform(rgb_img)
rgb_img_data = torch.unsqueeze(rgb_img_data, dim=0)

us_image=us_image[100:400, 140:500]
us_image = Image.fromarray(cv2.cvtColor(us_image, cv2.COLOR_BGR2RGB))
us_temp = max(us_image.size)

us_mask = Image.new('RGB', (us_temp, us_temp))
us_mask.paste(us_image, (0, 0))
us_mask = us_mask.resize((256, 256))


us_img_data = transform(us_mask)
us_img_data = torch.unsqueeze(us_img_data, dim=0)
F = F.to(device)
P = P.to(device)
D = D.to(device)
rgb_img_data= rgb_img_data.to(device)
us_img_data= us_img_data.to(device)
F_out, P_out, D_out = model(rgb_img_data, us_img_data, F, P, D)

P_out=P_out.squeeze(dim=0)
P_out=P_out.cpu().detach().numpy()/10000
P=P.squeeze(dim=0)
P=P.cpu().detach().numpy()/10000
print(P_out)
print(P)
print(D)
print(F)

# %%
# Out:
# [ 0.5023335  -0.04636879  0.06446359]
# [ 0.48316693 -0.04895843  0.06329051]
# tensor([[ 0.7368,  0.6761, -0.0059,  0.0020]], device='cuda:0')
# tensor([[-22.2000,   2.5000,  62.7000]], device='cuda:0')

# %%
#test_path=r"C:\Users\Paradox\Desktop\git\multimodel\val_data\P_real"
#P=np.load(os.path.join(test_path,"127.npy"))
#P=P*10000
#P=torch.Tensor(P)
#P=P.unsqueeze(dim=0)
test_path=r"C:\Users\Paradox\Desktop\test"
P=np.load(os.path.join(test_path,"P.npy"))
P=torch.Tensor(P)
#F=np.load(os.path.join(test_path,"F.npy"))
#F=torch.Tensor(F)
test_path=r"C:\Users\Paradox\Desktop\git\multimodel\val_data\Force"
F=np.load(os.path.join(test_path,"127.npy"))
F=F*100
F=torch.Tensor(F)
F=F.unsqueeze(dim=0)

test_path=r"C:\Users\Paradox\Desktop\git\multimodel\val_data\D_real"
D=np.load(os.path.join(test_path,"127.npy"))
D=torch.Tensor(D)
D=D.unsqueeze(dim=0)

image=cv2.imread(r"C:\Users\Paradox\Desktop\test\RGB_Image\25.png")
us_image=cv2.imread(r"C:\Users\Paradox\Desktop\test\Ultrasound_image\25.png")

rgb_img = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
rgb_temp = max(rgb_img.size)

rgb_mask = Image.new('RGB', (rgb_temp, rgb_temp))
rgb_mask.paste(rgb_img, (0, 0))
rgb_img = rgb_mask.resize((256, 256))



rgb_img_data = transform(rgb_img)
rgb_img_data = torch.unsqueeze(rgb_img_data, dim=0)

us_image=us_image[100:400, 140:500]
us_image = Image.fromarray(cv2.cvtColor(us_image, cv2.COLOR_BGR2RGB))
us_temp = max(us_image.size)

us_mask = Image.new('RGB', (us_temp, us_temp))
us_mask.paste(us_image, (0, 0))
us_mask = us_mask.resize((256, 256))


us_img_data = transform(us_mask)
us_img_data = torch.unsqueeze(us_img_data, dim=0)
F = F.to(device)
P = P.to(device)
D = D.to(device)
rgb_img_data= rgb_img_data.to(device)
us_img_data= us_img_data.to(device)
F_out, P_out, D_out = model(rgb_img_data, us_img_data, F, P, D)

# %%
P_out=P_out.squeeze(dim=0)
P_out=P_out.cpu().detach().numpy()/10000
P=P.squeeze(dim=0)
P=P.cpu().detach().numpy()/10000

# %%
print(P_out)
print(P)
print(D)
print(F)
# Out:
# [ 0.47090384 -0.05933581  0.07079428]
# [ 0.4722979  -0.05373874  0.08232375]
# tensor([[ 0.7096,  0.7041, -0.0111,  0.0253]], device='cuda:0')
# tensor([[-13.5341, 128.2526,  78.7489]], device='cuda:0')
